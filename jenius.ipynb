# %%
import os
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

resp = client.responses.create(

    model="gpt-4o",

    input=[{"role":"user","content":"BTC price?"}],

    tools=[{

        "type":"mcp",

        "server_label":"Jenius",

        "server_url":"https://mcp-jenius.rndm.io/sse",

        "headers":{"Authorization":f"Bearer {os.getenv('JENIUS_MCP_TOKEN')}"},

        "require_approval":"never"

    }],

    stream=False

)

print(resp.output_text)
# Out:
# Currently, the market analysis for Bitcoin (BTC) indicates a **long** position with a **high conviction**. The target price is **$110,000** with a stop loss at **$102,500**. This suggestion is short-term.
#
# The analysis highlights:
#
# - A rebound from $103K support.
# - Bullish sentiment despite recent profit-taking.
# - Institutional forecasts aiming for $110K resistance.
# - The current price suggests a high-reward opportunity below all-time highs due to macroeconomic uncertainty.
